# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#Testing
#Site: https://www.rebgv.org/
#Segment: /market-watch/
#Old Format:
#Page: /MLS-HPI-home-price-comparison.hpi.<area>.<sub-area>.<property type>.<day>.html
#Example: https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.greater_vancouver.detached.2020-2-1.html
#New Format (as of August 23rd, 2020):
#Page: /MLS-HPI-home-price-comparison.hpi.<area>.<sub-area>.<property type, nullable>.<day>.html
#Example: https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.greater_vancouver.all.detached.2020-7-1.html

linked = 'https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-7-1.html'

response = requests.get(linked)
soup = BeautifulSoup(response.text, 'html.parser')
# soup
result = soup.find_all('div', class_='hpi-graphics')
result
# Out:
# [<div class="hpi-graphics parbase">
#  <input id="propertyTypeLabels" type="hidden" value="Detached, Townhouse, Apartment, Residential (all types)"/>
#  <input id="momData_current" type="hidden" value="273.0,255.9,272.9,270.6"/>
#  <input id="momData_previous" type="hidden" value="270.5,253.7,272.2,269.0"/>
#  <input id="yoyData_current" type="hidden" value="273.0,255.9,272.9,270.6"/>
#  <input id="yoyData_previous" type="hidden" value="260.0,246.7,262.0,259.0"/>
#  <input id="dateLabel3Year" type="hidden" value="Jul 17,Aug 17,Sep 17,Oct 17,Nov 17,Dec 17,Jan 18,Feb 18,Mar 18,Apr 18,May 18,Jun 18,Jul 18,Aug 18,Sep 18,Oct 18,Nov 18,Dec 18,Jan 19,Feb 19,Mar 19,Apr 19,May 19,Jun 19,Jul 19,Aug 19,Sep 19,Oct 19,Nov 19,Dec 19,Jan 20,Feb 20,Mar 20,Apr 20,May 20,Jun 20,Jul 20"/>
#  <input id="data_apt" type="hidden" value="246.6,253.0,256.8,260.0,263.2,266.3,268.8,273.0,280.0,284.6,287.2,287.5,288.4,287.3,283.2,279.3,277.9,271.6,270.5,268.8,269.4,268.0,268.1,266.6,262.8,262.0,262.4,261.5,261.8,261.5,263.7,266.3,272.0,275.9,275.4,274.5,272.2,272.9"/>
#  <input id="data_detached" type="hidden" value="291.3,294.7,294.8,295.0,293.7,292.6,292.7,292.7,293.1,294.6,294.1,294.0,291.6,288.8,284.5,280.8,278.7,275.4,271.4,266.4,263.8,263.6,262.6,261.5,261.1,260.0,258.4,258.3,259.4,259.9,260.7,262.9,263.4,266.3,268.3,269.1,270.5,273.0"/>
#  <input id="data_townhouse" type="hidden" value="238.4,243.9,248.7,249.5,252.1,253.5,253.4,255.4,259.1,264.8,269.1,270.2,271.5,271.1,268.4,264.8,262.4,259.2,255.4,252.0,249.4,247.3,247.9,249.8,247.9,246.7,247.7,247.0,247.5,247.5,249.0,250.8,251.3,253.5,253.8,254.3,253.7,255.9"/>
#  <input id="data_residential" type="hidden" value="262.8,267.7,270.1,271.7,273.0,274.2,275.3,277.6,281.6,285.2,286.8,287.1,287.0,285.3,281.4,277.6,275.8,271.0,268.5,265.4,264.5,263.3,263.2,262.3,260.0,259.0,258.8,258.2,258.8,258.9,260.6,262.8,266.2,269.5,269.9,269.8,269.0,270.6"/>
#  <div class="results">
#  <div class="table-wrapper">
#  <div class="table-title-wrapper short">
#  <h2 class="table-title">Home Price Index for Greater Vancouver</h2>
#  <h3 class="table-subtitle">all</h3>
#  <div class="table-date">July 2020</div>
#  </div>
td>
#  <td>Apartment</td>
#  </tr>
#  <tr class="">
#  <td>Pitt Meadows</td>
#  <td>$498,700</td>
#  <td>294.1</td>
#  <td>-0.7</td>
#  <td>4.0</td>
#  <td>2.0</td>
#  <td>19.7</td>
#  <td>83.8</td>
#  <td>Apartment</td>
#  </tr>
#  <tr class="">
#  <td>North Vancouver</td>
#  <td>$582,600</td>
#  <td>237.6</td>
#  <td>1.3</td>
#  <td>4.3</td>
#  <td>5.0</td>
#  <td>5.8</td>
#  <td>55.3</td>
#  <td>Apartment</td>
#  </tr>
#  <tr class="">
#  <td>New Westminster</td>
#  <td>$530,700</td>
#  <td>300.7</td>
#  <td>0.3</td>
#  <td>4.1</td>
#  <td>3.0</td>
#  <td>12.2</td>
#  <td>78.6</td>
#  <td>Apartment</td>
#  </tr>
#  <tr class="">
#  <td>Maple Ridge</td>
#  <td>$361,200</td>
#  <td>257.9</td>
#  <td>-1.3</td>
#  <td>5.5</td>
#  <td>3.9</td>
#  <td>23.9</td>
#  <td>81.2</td>
#  <td>Apartment</td>
#  </tr>
#  <tr class="">
#  <td>Ladner</td>
#  <td>$515,800</td>
#  <td>240.8</td>
#  <td>0.8</td>
#  <td>0.9</td>
#  <td>1.9</td>
#  <td>4.1</td>
#  <td>42.3</td>
#  <td>Apartment</td>
#  </tr>
#  <tr class="">
#  <td>Coquitlam</td>
#  <td>$529,000</td>
#  <td>290.3</td>
#  <td>0.5</td>
#  <td>1.4</td>
#  <td>2.4</td>
#  <td>15.2</td>
#  <td>84.4</td>
#  <td>Apartment</td>
#  </tr>
#  <tr class="">
#  <td>Burnaby South</td>
#  <td>$674,500</td>
#  <td>270.8</td>
#  <td>0.6</td>
#  <td>1.9</td>
#  <td>3.2</td>
#  <td>5.7</td>
#  <td>64.2</td>
#  <td>Apartment</td>
#  </tr>
#  <tr class="">
#  <td>Burnaby North</td>
#  <td>$610,900</td>
#  <td>260.8</td>
#  <td>0.9</td>
#  <td>0.7</td>
#  <td>0.2</td>
#  <td>10.9</td>
#  <td>72.3</td>
#  <td>Apartment</td>
#  </tr>
#  <tr class="">
#  <td>Burnaby East</td>
#  <td>$733,200</td>
#  <td>281.3</td>
#  <td>-1.3</td>
#  <td>2.6</td>
#  <td>1.7</td>
#  <td>-0.7</td>
#  <td>54.4</td>
#  <td>Apartment</td>
#  </tr>
#  <tr class="">
#  <td>Lower Mainland</td>
#  <td>$655,900</td>
#  <td>281.0</td>
#  <td>0.3</td>
#  <td>2.7</td>
#  <td>3.9</td>
#  <td>11.7</td>
#  <td>71.4</td>
#  <td>Apartment</td>
#  </tr>
#  </tbody>
#  </table>
#  </div>
#  </div>
#  </div>
#  <!-- Month over Month -->
#  <div aria-hidden="true" class="table-title-wrapper">
#  <h2 class="table-title"><strong>Month over Month</strong> Price Index for Greater Vancouver</h2>
#  <h3 class="table-subtitle">all</h3>
#  <div class="table-date">July 2020</div>
#  </div>
#  <div aria-hidden="true" class="dropdown d-block d-sm-none">
#  <label for="type">Type:</label>
#  <div class="select-wrapper-short">
#  <select class="form-control custom-select" id="monthMobileSelect">
#  <option value="Detached">Detached</option>
#  <option value="Townhouse">Townhouse</option>
#  <option value="Apt">Apartment</option>
#  <option value="All">Residential</option>
#  </select>
#  </div>
#  </div>
#  <canvas aria-hidden="true" class="chart" id="monthOver"></canvas>
#  <div aria-hidden="true" class="mobileGraphs" id="monthMobile">
#  <canvas class="chart mobile" id="monthMobileDetached"></canvas>
#  <canvas class="chart mobile" id="monthMobileTownhouse"></canvas>
#  <canvas class="chart mobile" id="monthMobileApt"></canvas>
#  <canvas class="chart mobile" id="monthMobileAll"></canvas>
#  </div>
#  <div aria-hidden="true" class="legend-wrapper" id="month-legend"></div>
#  <!-- Year over Year -->
#  <div aria-hidden="true" class="table-title-wrapper">
#  <h2 class="table-title"><strong>Year over Year</strong> Price Index for Greater Vancouver</h2>
#  <h3 class="table-subtitle">all</h3>
#  <div class="table-date">July 2020</div>
#  </div>
#  <div aria-hidden="true" class="dropdown d-block d-sm-none">
#  <label for="type">Type:</label>
#  <div class="select-wrapper-short">
#  <select class="form-control custom-select" id="yearMobileSelect">
#  <option value="Detached">Detached</option>
#  <option value="Townhouse">Townhouse</option>
#  <option value="Apt">Apartment</option>
#  <option value="All">Residential</option>
#  </select>
#  </div>
#  </div>
#  <canvas aria-hidden="true" class="chart" id="yearOver"></canvas>
#  <div aria-hidden="true" class="mobileGraphs" id="yearMobile">
#  <canvas class="chart mobile" id="yearMobileDetached"></canvas>
#  <canvas class="chart mobile" id="yearMobileTownhouse"></canvas>
#  <canvas class="chart mobile" id="yearMobileApt"></canvas>
#  <canvas class="chart mobile" id="yearMobileAll"></canvas>
#  </div>
#  <div aria-hidden="true" class="legend-wrapper" id="year-legend"></div>
#  <!-- 3 Year Trend -->
#  <div aria-hidden="true" class="table-title-wrapper">
#  <h2 class="table-title">Price Index for Greater Vancouver</h2>
#  <h3 class="table-subtitle">all</h3>
#  <h2 class="table-date">3 Year Trend</h2>
#  </div>
#  <div class="line-chart">
#  <canvas aria-hidden="true" id="threeYearTrend"></canvas>
#  </div>
#  <div aria-hidden="true" class="legend-wrapper" id="three-yr-trend"></div>
#  <!-- new search -->
#  <div class="spacer-105"></div>
#  <div class="row-center">
#  <a class="btn btn-secondary" href="/market-watch/MLS-HPI-home-price-comparison.html">New search</a>
#  </div>
#  </div>
#  </div>]

# %%
home_dict = []

for year in range(2016, 2016):
    for month in range(1, 13):
        try:
            url = 'https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.' + str(year) + '-' + str(month) + '-1.html';
            r = requests.get(url)
            soup = BeautifulSoup(r.text, 'html.parser')

            home_table = soup.find('div', class_="table-wrapper")
            for home in home_table.find_all('tbody'):
                rows = home.find_all('tr')
                for row in rows:
                    area = row.find('td').text;
                    benchmark = row.find_all('td')[1].text
                    priceIndex = row.find_all('td')[2].text
                    oneMonthChange = row.find_all('td')[3].text
                    sixMonthChange = row.find_all('td')[4].text
                    oneYearChange = row.find_all('td')[5].text
                    threeYearChange = row.find_all('td')[6].text
                    fiveYearChange = row.find_all('td')[7].text
                    propertyType = row.find_all('td')[8].text
                    year = year;
                    month = month;

                    home_obj = {
                        "Area": area,
                        "Benchmark": benchmark,
                        "Price Index": priceIndex,
                        "1 Month +/-": oneMonthChange,
                        "6 Month +/-": sixMonthChange,
                        "1 Year +/-": oneYearChange,
                        "3 Year +/-": threeYearChange,
                        "5 Year +/-": fiveYearChange,
                        "Property Type": propertyType,
                        "Report Month": month,
                        "Report Year": year
                    }
                    home_dict.append(home_obj)  
        except:
            continue
                
print(home_dict)
# Out:
# []

# %%
vancouver_home_data = pd.DataFrame(home_dict)
vancouver_home_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-addcdf80a5dc> in <module>
# ----> 1 vancouver_home_data = pd.DataFrame(home_dict)
#       2 vancouver_home_data
#
# NameError: name 'pd' is not defined

# %%
# Export file as a CSV, without the Pandas index, but with the header
vancouver_home_data.to_csv("Vancouver Real Estate Board Data 201601 - 202005.csv", index=False, header=True)
