# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
#Testing
#Site: https://www.rebgv.org/
#Segment: /market-watch/
#Old Format:
#Page: /MLS-HPI-home-price-comparison.hpi.<area>.<sub-area>.<property type>.<YYYY-m-d>.html
#Example: https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.greater_vancouver.detached.2020-2-1.html
#New Format (as of August 23rd, 2020):
#Page: /MLS-HPI-home-price-comparison.hpi.<area>.<sub-area>.<property type, nullable>.<YYYY-m-d>.html
#Example: https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.greater_vancouver.all.detached.2020-7-1.html

linked = 'https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-7-1.html'

response = requests.get(linked)
# soup
soup = BeautifulSoup(response.text, 'html.parser')

# div main class: hpi-graphics
# div content class: table-wrapper
result = soup.find_all('div', class_='table-wrapper')
result

# %%
home_dict = []

for year in range(2005, 2021):
    for month in range(1, 13):
        print(str(year) + "-" + str(month))
        try:
            url = 'https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.' + str(year) + '-' + str(month) + '-1.html';
            print(url)
            r = requests.get(url)
            soup = BeautifulSoup(r.text, 'html.parser')

            home_table = soup.find('div', class_="table-wrapper")
            #print(home_table)
            for home in home_table.find_all('tbody'):
                rows = home.find_all('tr')
                for row in rows:
                    area = row.find('td').text;
                    benchmark = row.find_all('td')[1].text
                    priceIndex = row.find_all('td')[2].text
                    oneMonthChange = row.find_all('td')[3].text
                    sixMonthChange = row.find_all('td')[4].text
                    oneYearChange = row.find_all('td')[5].text
                    threeYearChange = row.find_all('td')[6].text
                    fiveYearChange = row.find_all('td')[7].text
                    propertyType = row.find_all('td')[8].text
                    year = year;
                    month = month;

                    home_obj = {
                        "Area": area,
                        "Benchmark": benchmark,
                        "Price Index": priceIndex,
                        "1 Month +/-": oneMonthChange,
                        "6 Month +/-": sixMonthChange,
                        "1 Year +/-": oneYearChange,
                        "3 Year +/-": threeYearChange,
                        "5 Year +/-": fiveYearChange,
                        "Property Type": propertyType,
                        "Report Month": month,
                        "Report Year": year
                    }
                    home_dict.append(home_obj)  
        except:
            continue

#print(home_dict)
# Out:
# 2005-1
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-1-1.html
# 2005-2
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-2-1.html
# 2005-3
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-3-1.html
# 2005-4
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-4-1.html
# 2005-5
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-5-1.html
# 2005-6
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-6-1.html
# 2005-7
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-7-1.html
# 2005-8
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-8-1.html
# 2005-9
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-9-1.html
# 2005-10
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-10-1.html
# 2005-11
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-11-1.html
# 2005-12
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2005-12-1.html
# 2006-1
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-1-1.html
# 2006-2
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-2-1.html
# 2006-3
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-3-1.html
# 2006-4
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-4-1.html
# 2006-5
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-5-1.html
# 2006-6
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-6-1.html
# 2006-7
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-7-1.html
# 2006-8
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-8-1.html
# 2006-9
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-9-1.html
# 2006-10
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-10-1.html
# 2006-11
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-11-1.html
# 2006-12
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2006-12-1.html
# 2007-1
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2007-1-1.html
# 2007-2
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2007-2-1.html
# 2007-3
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2007-3-1.html
# 2007-4
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2007-4-1.html
# 2007-5
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2007-5-1.html
# 2007-6
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2007-6-1.html
# 2007-7
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2007-7-1.html
# 2007-8
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2007-8-1.html
# 2007-9
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2007
6
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2016-6-1.html
# 2016-7
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2016-7-1.html
# 2016-8
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2016-8-1.html
# 2016-9
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2016-9-1.html
# 2016-10
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2016-10-1.html
# 2016-11
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2016-11-1.html
# 2016-12
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2016-12-1.html
# 2017-1
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-1-1.html
# 2017-2
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-2-1.html
# 2017-3
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-3-1.html
# 2017-4
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-4-1.html
# 2017-5
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-5-1.html
# 2017-6
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-6-1.html
# 2017-7
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-7-1.html
# 2017-8
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-8-1.html
# 2017-9
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-9-1.html
# 2017-10
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-10-1.html
# 2017-11
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-11-1.html
# 2017-12
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2017-12-1.html
# 2018-1
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-1-1.html
# 2018-2
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-2-1.html
# 2018-3
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-3-1.html
# 2018-4
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-4-1.html
# 2018-5
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-5-1.html
# 2018-6
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-6-1.html
# 2018-7
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-7-1.html
# 2018-8
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-8-1.html
# 2018-9
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-9-1.html
# 2018-10
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-10-1.html
# 2018-11
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-11-1.html
# 2018-12
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2018-12-1.html
# 2019-1
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-1-1.html
# 2019-2
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-2-1.html
# 2019-3
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-3-1.html
# 2019-4
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-4-1.html
# 2019-5
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-5-1.html
# 2019-6
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-6-1.html
# 2019-7
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-7-1.html
# 2019-8
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-8-1.html
# 2019-9
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-9-1.html
# 2019-10
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-10-1.html
# 2019-11
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-11-1.html
# 2019-12
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2019-12-1.html
# 2020-1
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-1-1.html
# 2020-2
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-2-1.html
# 2020-3
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-3-1.html
# 2020-4
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-4-1.html
# 2020-5
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-5-1.html
# 2020-6
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-6-1.html
# 2020-7
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-7-1.html
# 2020-8
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-8-1.html
# 2020-9
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-9-1.html
# 2020-10
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-10-1.html
# 2020-11
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-11-1.html
# 2020-12
# https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.all.2020-12-1.html

# %%
vhd = pd.DataFrame(home_dict)
vhd
#Save each property types into seperated files
#Four
#alltypes = vhd.loc[(vhd["Property Type"]=="Residential - All Types") & (vhd["Report Month"]==7) & (vhd["Report Year"]==2020)]
alltypes = vhd.loc[(vhd["Property Type"]=="Residential - All Types")]
alltypes = alltypes.sort_values(["Area", "Property Type"], ascending=True)
alltypes.to_csv("Vancouver Real Estate Board Data (All Types) 200501 - 202007.csv", index=False, header=True)
apartment = vhd.loc[(vhd["Property Type"]=="Apartment")]
apartment = apartment.sort_values(["Area", "Property Type"], ascending=True)
apartment.to_csv("Vancouver Real Estate Board Data (Apartment) 200501 - 202007.csv", index=False, header=True)
detached = vhd.loc[(vhd["Property Type"]=="Detached")]
detached = detached.sort_values(["Area", "Property Type"], ascending=True)
detached.to_csv("Vancouver Real Estate Board Data (Detached) 200501 - 202007.csv", index=False, header=True)
townhouse = vhd.loc[(vhd["Property Type"]=="Townhouse")]
townhouse = townhouse.sort_values(["Area", "Property Type"], ascending=True)
townhouse.to_csv("Vancouver Real Estate Board Data (Townhouse) 200501 - 202007.csv", index=False, header=True)

# %%
# Export file as a CSV, without the Pandas index, but with the header
#vancouver_home_data.to_csv("Vancouver Real Estate Board Data 201601 - 202007.csv", index=False, header=True)
