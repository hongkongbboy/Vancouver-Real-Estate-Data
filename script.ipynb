# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#Testing
linked = 'https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.greater_vancouver.detached.2020-2-1.html'

response = requests.get(linked)
soup = BeautifulSoup(response.text, 'html.parser')
# soup
result = soup.find_all('div', class_='hpi-graphics')
result
# Out:
# [<div class="hpi-graphics parbase">
#  <input id="propertyTypeLabels" type="hidden" value="Detached"/>
#  <input id="momData_current" type="hidden" value="263.4,"/>
#  <input id="momData_previous" type="hidden" value="262.9,"/>
#  <input id="yoyData_current" type="hidden" value="263.4,"/>
#  <input id="yoyData_previous" type="hidden" value="263.8,"/>
#  <input id="dateLabel3Year" type="hidden" value="Feb 17,Mar 17,Apr 17,May 17,Jun 17,Jul 17,Aug 17,Sep 17,Oct 17,Nov 17,Dec 17,Jan 18,Feb 18,Mar 18,Apr 18,May 18,Jun 18,Jul 18,Aug 18,Sep 18,Oct 18,Nov 18,Dec 18,Jan 19,Feb 19,Mar 19,Apr 19,May 19,Jun 19,Jul 19,Aug 19,Sep 19,Oct 19,Nov 19,Dec 19,Jan 20,Feb 20"/>
#  <input id="data_apt" type="hidden" value=""/>
#  <input id="data_detached" type="hidden" value="269.1,270.3,274.3,280.4,288.1,291.3,294.7,294.8,295.0,293.7,292.6,292.7,292.7,293.1,294.6,294.1,294.0,291.6,288.8,284.5,280.8,278.7,275.4,271.4,266.4,263.8,263.6,262.6,261.5,261.1,260.0,258.4,258.3,259.4,259.9,260.7,262.9,263.4"/>
#  <input id="data_townhouse" type="hidden" value=""/>
#  <input id="data_residential" type="hidden" value=""/>
#  <div class="results">
#  <div class="table-wrapper">
#  <div class="table-title-wrapper short">
#  <h2 class="table-title">Home Price Index for greater vancouver</h2>
#  <div class="table-date">February 2020</div>
#  </div>
#  <div id="hpiTable_wrapper">
#  <div class="tbl-scroll">
#  <table id="hpiTableArea">
#  <!-- table will have 'Area' column if area == all -->
#  <thead>
#  <tr>
#  <th>Benchmark</th>
#  <th>Price Index</th>
#  <th>1 Month +/-</th>
#  <th>6 Month +/-</th>
#  <th>1 Year +/-</th>
#  <th>3 Year +/-</th>
#  <th>5 Year +/-</th>
#  <th>Property Type</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>$1,425,800</td>
#  <td>263.4</td>
#  <td>0.2</td>
#  <td>1.9</td>
#  <td>-0.2</td>
#  <td>-2.6</td>
#  <td>38.7</td>
#  <td>Detached</td>
#  </tr>
#  </tbody>
#  </table>
#  </div>
#  </div>
#  </div>
#  <!-- Month over Month -->
#  <div aria-hidden="true" class="table-title-wrapper">
#  <h2 class="table-title"><strong>Month over Month</strong> Price Index for greater vancouver</h2>
#  <div class="table-date">February 2020</div>
#  </div>
#  <div aria-hidden="true" class="dropdown d-block d-sm-none">
#  <label for="type">Type:</label>
#  <div class="select-wrapper-short">
#  <select class="form-control custom-select" id="monthMobileSelect">
#  <option value="Detached">Detached</option>
#  <option value="Townhouse">Townhouse</option>
#  <option value="Apt">Apartment</option>
#  <option value="All">Residential</option>
#  </select>
#  </div>
#  </div>
#  <canvas aria-hidden="true" class="chart" id="monthOver"></canvas>
#  <div aria-hidden="true" class="mobileGraphs" id="monthMobile">
#  <canvas class="chart mobile" id="monthMobileDetached"></canvas>
#  <canvas class="chart mobile" id="monthMobileTownhouse"></canvas>
#  <canvas class="chart mobile" id="monthMobileApt"></canvas>
#  <canvas class="chart mobile" id="monthMobileAll"></canvas>
#  </div>
#  <div aria-hidden="true" class="legend-wrapper" id="month-legend"></div>
#  <!-- Year over Year -->
#  <div aria-hidden="true" class="table-title-wrapper">
#  <h2 class="table-title"><strong>Year over Year</strong> Price Index for greater vancouver</h2>
#  <div class="table-date">February 2020</div>
#  </div>
#  <div aria-hidden="true" class="dropdown d-block d-sm-none">
#  <label for="type">Type:</label>
#  <div class="select-wrapper-short">
#  <select class="form-control custom-select" id="yearMobileSelect">
#  <option value="Detached">Detached</option>
#  <option value="Townhouse">Townhouse</option>
#  <option value="Apt">Apartment</option>
#  <option value="All">Residential</option>
#  </select>
#  </div>
#  </div>
#  <canvas aria-hidden="true" class="chart" id="yearOver"></canvas>
#  <div aria-hidden="true" class="mobileGraphs" id="yearMobile">
#  <canvas class="chart mobile" id="yearMobileDetached"></canvas>
#  <canvas class="chart mobile" id="yearMobileTownhouse"></canvas>
#  <canvas class="chart mobile" id="yearMobileApt"></canvas>
#  <canvas class="chart mobile" id="yearMobileAll"></canvas>
#  </div>
#  <div aria-hidden="true" class="legend-wrapper" id="year-legend"></div>
#  <!-- 3 Year Trend -->
#  <div aria-hidden="true" class="table-title-wrapper">
#  <h2 class="table-title">Price Index for greater vancouver</h2>
#  <h2 class="table-date">3 Year Trend</h2>
#  </div>
#  <div class="line-chart">
#  <canvas aria-hidden="true" id="threeYearTrend"></canvas>
#  </div>
#  <div aria-hidden="true" class="legend-wrapper" id="three-yr-trend"></div>
#  <!-- new search -->
#  <div class="spacer-105"></div>
#  <div class="row-center">
#  <a class="btn btn-secondary" href="/market-watch/MLS-HPI-home-price-comparison.html">New search</a>
#  </div>
#  </div>
#  </div>]

# %%
home_dict = []

for year in range(2016, 2021):
    for month in range(1, 13):
        try:
            url = 'https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.' + str(year) + '-' + str(month) + '-1.html';
            r = requests.get(url)
            soup = BeautifulSoup(r.text, 'html.parser')

            home_table = soup.find('div', class_="table-wrapper")
            for home in home_table.find_all('tbody'):
                rows = home.find_all('tr')
                for row in rows:
                    area = row.find('td').text;
                    benchmark = row.find_all('td')[1].text
                    priceIndex = row.find_all('td')[2].text
                    oneMonthChange = row.find_all('td')[3].text
                    sixMonthChange = row.find_all('td')[4].text
                    oneYearChange = row.find_all('td')[5].text
                    threeYearChange = row.find_all('td')[6].text
                    fiveYearChange = row.find_all('td')[7].text
                    propertyType = row.find_all('td')[8].text
                    year = year;
                    month = month;

                    home_obj = {
                        "Area": area,
                        "Benchmark": benchmark,
                        "Price Index": priceIndex,
                        "1 Month +/-": oneMonthChange,
                        "6 Month +/-": sixMonthChange,
                        "1 Year +/-": oneYearChange,
                        "3 Year +/-": threeYearChange,
                        "5 Year +/-": fiveYearChange,
                        "Property Type": propertyType,
                        "Report Month": month,
                        "Report Year": year
                    }
                    home_dict.append(home_obj)  
        except:
            continue
                
print(home_dict)

# %%
vancouver_home_data = pd.DataFrame(home_dict)
vancouver_home_data

# %%
# Export file as a CSV, without the Pandas index, but with the header
vancouver_home_data.to_csv("Vancouver Real Estate Board Data 201601 - 202005.csv", index=False, header=True)
