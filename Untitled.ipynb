# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#Testing
linked = 'https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.greater_vancouver.detached.2020-2-1.html'

response = requests.get(linked)
soup = BeautifulSoup(response.text, 'html.parser')
# soup
result = soup.find_all('div', class_='hpi-graphics')
result
# Out:
# [<div class="hpi-graphics parbase">
#  <input id="propertyTypeLabels" type="hidden" value="Detached"/>
#  <input id="momData_current" type="hidden" value="263.4,"/>
#  <input id="momData_previous" type="hidden" value="262.9,"/>
#  <input id="yoyData_current" type="hidden" value="263.4,"/>
#  <input id="yoyData_previous" type="hidden" value="263.8,"/>
#  <input id="dateLabel3Year" type="hidden" value="Feb 17,Mar 17,Apr 17,May 17,Jun 17,Jul 17,Aug 17,Sep 17,Oct 17,Nov 17,Dec 17,Jan 18,Feb 18,Mar 18,Apr 18,May 18,Jun 18,Jul 18,Aug 18,Sep 18,Oct 18,Nov 18,Dec 18,Jan 19,Feb 19,Mar 19,Apr 19,May 19,Jun 19,Jul 19,Aug 19,Sep 19,Oct 19,Nov 19,Dec 19,Jan 20,Feb 20"/>
#  <input id="data_apt" type="hidden" value=""/>
#  <input id="data_detached" type="hidden" value="269.1,270.3,274.3,280.4,288.1,291.3,294.7,294.8,295.0,293.7,292.6,292.7,292.7,293.1,294.6,294.1,294.0,291.6,288.8,284.5,280.8,278.7,275.4,271.4,266.4,263.8,263.6,262.6,261.5,261.1,260.0,258.4,258.3,259.4,259.9,260.7,262.9,263.4"/>
#  <input id="data_townhouse" type="hidden" value=""/>
#  <input id="data_residential" type="hidden" value=""/>
#  <div class="results">
#  <div class="table-wrapper">
#  <div class="table-title-wrapper short">
#  <h2 class="table-title">Home Price Index for greater vancouver</h2>
#  <div class="table-date">February 2020</div>
#  </div>
#  <div id="hpiTable_wrapper">
#  <div class="tbl-scroll">
#  <table id="hpiTableArea">
#  <!-- table will have 'Area' column if area == all -->
#  <thead>
#  <tr>
#  <th>Benchmark</th>
#  <th>Price Index</th>
#  <th>1 Month +/-</th>
#  <th>6 Month +/-</th>
#  <th>1 Year +/-</th>
#  <th>3 Year +/-</th>
#  <th>5 Year +/-</th>
#  <th>Property Type</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>$1,425,800</td>
#  <td>263.4</td>
#  <td>0.2</td>
#  <td>1.9</td>
#  <td>-0.2</td>
#  <td>-2.6</td>
#  <td>38.7</td>
#  <td>Detached</td>
#  </tr>
#  </tbody>
#  </table>
#  </div>
#  </div>
#  </div>
#  <!-- Month over Month -->
#  <div aria-hidden="true" class="table-title-wrapper">
#  <h2 class="table-title"><strong>Month over Month</strong> Price Index for greater vancouver</h2>
#  <div class="table-date">February 2020</div>
#  </div>
#  <div aria-hidden="true" class="dropdown d-block d-sm-none">
#  <label for="type">Type:</label>
#  <div class="select-wrapper-short">
#  <select class="form-control custom-select" id="monthMobileSelect">
#  <option value="Detached">Detached</option>
#  <option value="Townhouse">Townhouse</option>
#  <option value="Apt">Apartment</option>
#  <option value="All">Residential</option>
#  </select>
#  </div>
#  </div>
#  <canvas aria-hidden="true" class="chart" id="monthOver"></canvas>
#  <div aria-hidden="true" class="mobileGraphs" id="monthMobile">
#  <canvas class="chart mobile" id="monthMobileDetached"></canvas>
#  <canvas class="chart mobile" id="monthMobileTownhouse"></canvas>
#  <canvas class="chart mobile" id="monthMobileApt"></canvas>
#  <canvas class="chart mobile" id="monthMobileAll"></canvas>
#  </div>
#  <div aria-hidden="true" class="legend-wrapper" id="month-legend"></div>
#  <!-- Year over Year -->
#  <div aria-hidden="true" class="table-title-wrapper">
#  <h2 class="table-title"><strong>Year over Year</strong> Price Index for greater vancouver</h2>
#  <div class="table-date">February 2020</div>
#  </div>
#  <div aria-hidden="true" class="dropdown d-block d-sm-none">
#  <label for="type">Type:</label>
#  <div class="select-wrapper-short">
#  <select class="form-control custom-select" id="yearMobileSelect">
#  <option value="Detached">Detached</option>
#  <option value="Townhouse">Townhouse</option>
#  <option value="Apt">Apartment</option>
#  <option value="All">Residential</option>
#  </select>
#  </div>
#  </div>
#  <canvas aria-hidden="true" class="chart" id="yearOver"></canvas>
#  <div aria-hidden="true" class="mobileGraphs" id="yearMobile">
#  <canvas class="chart mobile" id="yearMobileDetached"></canvas>
#  <canvas class="chart mobile" id="yearMobileTownhouse"></canvas>
#  <canvas class="chart mobile" id="yearMobileApt"></canvas>
#  <canvas class="chart mobile" id="yearMobileAll"></canvas>
#  </div>
#  <div aria-hidden="true" class="legend-wrapper" id="year-legend"></div>
#  <!-- 3 Year Trend -->
#  <div aria-hidden="true" class="table-title-wrapper">
#  <h2 class="table-title">Price Index for greater vancouver</h2>
#  <h2 class="table-date">3 Year Trend</h2>
#  </div>
#  <div class="line-chart">
#  <canvas aria-hidden="true" id="threeYearTrend"></canvas>
#  </div>
#  <div aria-hidden="true" class="legend-wrapper" id="three-yr-trend"></div>
#  <!-- new search -->
#  <div class="spacer-105"></div>
#  <div class="row-center">
#  <a class="btn btn-secondary" href="/market-watch/MLS-HPI-home-price-comparison.html">New search</a>
#  </div>
#  </div>
#  </div>]

# %%
home_dict = []

for year in range(2016, 2021):
    for month in range(1, 13):
        try:
            url = 'https://www.rebgv.org/market-watch/MLS-HPI-home-price-comparison.hpi.all.all.' + str(year) + '-' + str(month) + '-1.html';
            r = requests.get(url)
            soup = BeautifulSoup(r.text, 'html.parser')

            home_table = soup.find('div', class_="table-wrapper")
            for home in home_table.find_all('tbody'):
                rows = home.find_all('tr')
                for row in rows:
                    area = row.find('td').text;
                    benchmark = row.find_all('td')[1].text
                    priceIndex = row.find_all('td')[2].text
                    oneMonthChange = row.find_all('td')[3].text
                    sixMonthChange = row.find_all('td')[4].text
                    oneYearChange = row.find_all('td')[5].text
                    threeYearChange = row.find_all('td')[6].text
                    fiveYearChange = row.find_all('td')[7].text
                    propertyType = row.find_all('td')[8].text
                    year = year;
                    month = month;

                    home_obj = {
                        "Area": area,
                        "Benchmark": benchmark,
                        "Price Index": priceIndex,
                        "1 Month +/-": oneMonthChange,
                        "6 Month +/-": sixMonthChange,
                        "1 Year +/-": oneYearChange,
                        "3 Year +/-": threeYearChange,
                        "5 Year +/-": fiveYearChange,
                        "Property Type": propertyType,
                        "Report Month": month,
                        "Report Year": year
                    }
                    home_dict.append(home_obj)  
        except:
            continue
                
print(home_dict)
# Out:
# [{'Area': 'Greater Vancouver', 'Benchmark': '$784,000', 'Price Index': '205.7', '1 Month +/-': '2.3', '6 Month +/-': '10.6', '1 Year +/-': '20.9', '3 Year +/-': '32.1', '5 Year +/-': '36.1', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Lower Mainland', 'Benchmark': '$694,600', 'Price Index': '194.6', '1 Month +/-': '2.2', '6 Month +/-': '10.0', '1 Year +/-': '19.4', '3 Year +/-': '28.5', '5 Year +/-': '32.3', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Bowen Island', 'Benchmark': '$649,400', 'Price Index': '140.8', '1 Month +/-': '1.1', '6 Month +/-': '5.7', '1 Year +/-': '11.8', '3 Year +/-': '13.4', '5 Year +/-': '16.8', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Burnaby East', 'Benchmark': '$720,000', 'Price Index': '199.7', '1 Month +/-': '1.0', '6 Month +/-': '5.4', '1 Year +/-': '18.1', '3 Year +/-': '28.2', '5 Year +/-': '33.6', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Burnaby North', 'Benchmark': '$648,100', 'Price Index': '195.7', '1 Month +/-': '2.4', '6 Month +/-': '8.1', '1 Year +/-': '18.0', '3 Year +/-': '27.8', '5 Year +/-': '32.3', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Burnaby South', 'Benchmark': '$711,600', 'Price Index': '201.0', '1 Month +/-': '1.0', '6 Month +/-': '7.4', '1 Year +/-': '15.7', '3 Year +/-': '28.4', '5 Year +/-': '31.5', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Coquitlam', 'Benchmark': '$662,500', 'Price Index': '196.5', '1 Month +/-': '2.4', '6 Month +/-': '11.5', '1 Year +/-': '21.4', '3 Year +/-': '33.9', '5 Year +/-': '38.9', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Ladner', 'Benchmark': '$782,500', 'Price Index': '220.3', '1 Month +/-': '5.9', '6 Month +/-': '20.8', '1 Year +/-': '34.9', '3 Year +/-': '44.5', '5 Year +/-': '49.7', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Maple Ridge', 'Benchmark': '$490,800', 'Price Index': '156.3', '1 Month +/-': '2.1', '6 Month +/-': '7.3', '1 Year +/-': '13.5', '3 Year +/-': '16.6', '5 Year +/-': '18.4', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'New Westminster', 'Benchmark': '$436,600', 'Price Index': '192.1', '1 Month +/-': '3.1', '6 Month +/-': '8.6', '1 Year +/-': '16.1', '3 Year +/-': '24.3', '5 Year +/-': '27.4', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'North Vancouver', 'Benchmark': '$862,800', 'Price Index': '193.9', '1 Month +/-': '1.9', '6 Month +/-': '12.7', '1 Year +/-': '21.8', '3 Year +/-': '35.1', '5 Year +/-': '42.6', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Pitt Meadows', 'Benchmark': '$467,400', 'Price Index': '169.9', '1 Month +/-': '1.4', '6 Month +/-': '6.3', '1 Year +/-': '11.5', '3 Year +/-': '20.5', '5 Year +/-': '22.8', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Port Coquitlam', 'Benchmark': '$525,500', 'Price Index': '179.9', '1 Month +/-': '2.6', '6 Month +/-': '10.1', '1 Year +/-': '20.3', '3 Year +/-': '26.8', '5 Year +/-': '28.7', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Port Moody', 'Benchmark': '$662,400', 'Price Index': '183.1', '1 Month +/-': '2.0', '6 Month +/-': '10.7', '1 Year +/-': '21.0', '3 Year +/-': '32.9', '5 Year +/-': '35.1', 'Property Type': 'Residential - All Types', 'Report Month': 1, 'Report Year': 2016}, {'Area': 'Richmond', 'Benchmark': '$722,600', 'Price Index': '215.7', '1 Month +/-': '2.5', '6 Month +/-': '11.8', '1 Year +/-': '22.5', '3 Year +/-': '31.8', '5 Year +/-': '31.1', 'Property Type': 'Residential - All Type ...

# %%
vancouver_home_data = pd.DataFrame(home_dict)
vancouver_home_data
# Out:
#      1 Month +/- 1 Year +/- 3 Year +/- 5 Year +/- 6 Month +/-  \
# 0            2.3       20.9       32.1       36.1        10.6
# 1            2.2       19.4       28.5       32.3        10.0
# 2            1.1       11.8       13.4       16.8         5.7
# 3            1.0       18.1       28.2       33.6         5.4
# 4            2.4       18.0       27.8       32.3         8.1
# 5            1.0       15.7       28.4       31.5         7.4
# 6            2.4       21.4       33.9       38.9        11.5
# 7            5.9       34.9       44.5       49.7        20.8
# 8            2.1       13.5       16.6       18.4         7.3
# 9            3.1       16.1       24.3       27.4         8.6
# 10           1.9       21.8       35.1       42.6        12.7
# 11           1.4       11.5       20.5       22.8         6.3
# 12           2.6       20.3       26.8       28.7        10.1
# 13           2.0       21.0       32.9       35.1        10.7
# 14           2.5       22.5       31.8       31.1        11.8
# 15           5.3       17.7       37.1       36.4        10.0
# 16           1.7       13.4       12.8       15.0         5.8
# 17           4.5       43.0       56.5       72.5        24.3
# 18           2.7       24.3       40.4       49.8        10.9
# 19           1.8       22.1       36.1       41.4        11.5
# 20           3.0       25.8       44.0       63.9        11.3
# 21           2.3       11.2       23.2       14.5         5.7
# 22           2.8       27.4       42.9       52.4        12.3
# 23           2.7       24.9       37.3       46.0        11.8
# 24           1.1       11.8       13.4       16.8         5.7
# 25           2.4       32.5       45.3       54.9        11.7
# 26           2.8       28.4       44.6       59.1        10.3
# 27           1.2       23.9       42.4       58.7         8.3
# 28           2.3       26.5       41.5       53.1        12.5
# 29           9.2       46.3       56.5       69.2        28.7
# ...          ...        ...        ...        ...         ...
# 4369        -0.9        2.2        2.7       52.4         4.0
# 4370         0.8        4.5       22.5       76.1         7.3
# 4371        -0.8        0.7       11.4       60.9         4.7
# 4372         0.4        0.7       15.6       46.5         4.9
# 4373        -0.1        2.6        5.0       48.2         4.2
# 4374        -0.4       -1.5       14.9       63.8        -3.6
# 4375         1.3        5.1       -0.9       43.2         4.0
# 4376         1.3        2.7        5.0       50.7         4.1
# 4377         0.1        0.8       -0.5       40.3        -0.8
# 4378        -0.3        3.1       21.6       72.5        -3.5
# 4379        -0.3        3.0       14.4       66.3         5.0
# 4380        -0.5        2.3       18.3       73.4         4.6
# 4381        -0.5       -0.2        9.4       58.1         4.0
# 4382         0.8        1.4       16.9       77.6         4.6
# 4383         0.9        0.4       11.2       66.7         4.9
# 4384         0.3        3.3       23.9       86.8         3.1
# 4385         0.3       -1.3        6.9       46.2         3.4
# 4386        -0.1        2.8       31.7       82.2         3.8
# 4387        -0.3       -0.8       19.8       82.1         3.4
# 4388         0.5        3.6       12.8       52.8         5.8
# 4389        -0.1        1.4       28.6       85.0         3.7
# 4390        -0.4        2.9       23.8       87.2         3.5
# 4391        -1.5        4.8       21.1       86.7         5.0
# 4392         0.0        2.3       17.8       73.5         4.1
# 4393        -3.1       -5.1       11.9       76.8        -3.4
# 4394         0.7       -2.0        6.7       45.8         3.0
# 4395        -1.2        1.6        9.7       68.7         4.9
# 4396        -0.6        5.6        7.4       52.0         6.8
# 4397         1.0       -1.6       -5.4       30.3        -1.6
# 4398        -4.5       -4.1       15.6       83.9        -3.9
#
#                    Area   Benchmark Price Index            Property Type  \
# 0     Greater Vancouver    $784,000       205.7  Residential - All Types
# 1        Lower Mainland    $694,600       194.6  Residential - All Types
# 2          Bowen Island    $649,400       140.8  Residential - All Types
# 3          Burnaby East    $720,000       199.7  Residential - All Types
# 4         Burnaby North    $648,100       195.7  Residential - All Types
# 5         Burnaby South    $711,600       201.0  Residential - All Types
# 6             Coquitlam    $662,500       196.5  Residential - All Types
# 7                Ladner    $782,500       220.3  Residential - All Types
# 8           Maple Ridge    $490,800       156.3  Residential - All Types
# 9       New Westminster    $436,600       192.1  Residential - All Types
# 10      North Vancouver    $862,800       193.9  Residential - All Types
# 11         Pitt Meadows    $467,400       169.9  Residential - All Types
# 12       Port Coquitlam    $525,500       179.9  Residential - All Types
# 13           Port Moody    $662,400       183.1  Residential - All Types
# 14             Richmond    $722,600       215.7  Residential - All Types
# 15             Squamish    $520,800       165.7  Residential - All Types
# 16       Sunshine Coast    $400,500       140.3  Residential - All Types
# 17           Tsawwassen    $894,500       231.9  Residential - All Types
# 18       Vancouver East    $844,000       250.8  Residential - All Types
# 19       Vancouver West  $1,068,900       223.2  Residential - All Types
# 20       West Vancouver  $2,153,400       237.1  Residential - All Types
# 21             Whistler    $576,700       134.4  Residential - All Types
# 22    Greater Vancouver  $1,284,500       237.3                 Detached
# 23       Lower Mainland  $1,010,500       215.5                 Detached
# 24         Bowen Island    $649,400       140.8                 Detached
# 25         Burnaby East  $1,025,000       229.2                 Detached
# 26        Burnaby North  $1,290,200       249.5                 Detached
# 27        Burnaby South  $1,314,800       251.7                 Detached
# 28            Coquitlam    $984,500       218.5                 Detached
# 29               Ladner  $1,010,700       241.9                 Detached
# ...                 ...         ...         ...                      ...
# 4369    North Vancouver    $974,200       236.7                Townhouse
# 4370       Pitt Meadows    $633,000       273.9                Townhouse
# 4371     Port Coquitlam    $647,200       245.0                Townhouse
# 4372         Port Moody    $648,600       219.2                Townhouse
# 4373           Richmond    $793,500       260.6                Townhouse
# 4374           Squamish    $683,100       224.6                Townhouse
# 4375         Tsawwassen    $635,900       249.3                Townhouse
# 4376     Vancouver East    $905,000       287.8                Townhouse
# 4377     Vancouver West  $1,125,000       263.0                Townhouse
# 4378           Whistler    $907,900       218.9                Townhouse
# 4379  Greater Vancouver    $686,500       274.5                Apartment
# 4380     Lower Mainland    $657,300       281.6                Apartment
# 4381       Burnaby East    $746,500       286.4                Apartment
# 4382      Burnaby North    $623,500       266.2                Apartment
# 4383      Burnaby South    $678,900       272.6                Apartment
# 4384          Coquitlam    $534,300       293.2                Apartment
# 4385             Ladner    $515,500       240.7                Apartment
# 4386        Maple Ridge    $360,500       257.4                Apartment
# 4387    New Westminster    $524,700       297.3                Apartment
# 4388    North Vancouver    $577,200       235.4                Apartment
# 4389       Pitt Meadows    $500,100       294.9                Apartment
# 4390     Port Coquitlam    $463,700       277.3                Apartment
# 4391         Port Moody    $661,100       275.5                Apartment
# 4392           Richmond    $652,800       279.5                Apartment
# 4393           Squamish    $480,000       236.6                Apartment
# 4394         Tsawwassen    $548,000       236.0                Apartment
# 4395     Vancouver East    $595,300       334.6                Apartment
# 4396     Vancouver West    $801,300       260.0                Apartment
# 4397     West Vancouver  $1,006,000       204.4                Apartment
# 4398           Whistler    $479,700       187.9                Apartment
#
#       Report Month  Report Year
# 0                1         2016
# 1                1         2016
# 2                1         2016
# 3                1         2016
# 4                1         2016
# 5                1         2016
# 6                1         2016
# 7                1         2016
# 8                1         2016
# 9                1         2016
# 10               1         2016
# 11               1         2016
# 12               1         2016
# 13               1         2016
# 14               1         2016
# 15               1         2016
# 16               1         2016
# 17               1         2016
# 18               1         2016
# 19               1         2016
# 20               1         2016
# 21               1         2016
# 22               1         2016
# 23               1         2016
# 24               1         2016
# 25               1         2016
# 26               1         2016
# 27               1         2016
# 28               1         2016
# 29               1         2016
# ...            ...          ...
# 4369             5         2020
# 4370             5         2020
# 4371             5         2020
# 4372             5         2020
# 4373             5         2020
# 4374             5         2020
# 4375             5         2020
# 4376             5         2020
# 4377             5         2020
# 4378             5         2020
# 4379             5         2020
# 4380             5         2020
# 4381             5         2020
# 4382             5         2020
# 4383             5         2020
# 4384             5         2020
# 4385             5         2020
# 4386             5         2020
# 4387             5         2020
# 4388             5         2020
# 4389             5         2020
# 4390             5         2020
# 4391             5         2020
# 4392             5         2020
# 4393             5         2020
# 4394             5         2020
# 4395             5         2020
# 4396             5         2020
# 4397             5         2020
# 4398             5         2020
#
# [4399 rows x 11 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
vancouver_home_data.to_csv("Vancouver Real Estate Board Data 201601 - 202005.csv", index=False, header=True)
